# %%
#Import libraries
import pandas as pd 
import numpy as np
import os

# %%
path = r'C:\Users\Zarqa Ayub\Instacart Basket Analysis'

# %%
df_csm = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'customers.csv'), index_col = False)

# %%
df_csm.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
df_csm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   user_id       206209 non-null  int64
#  1   First Name    194950 non-null  object
#  2   Surnam        206209 non-null  object
#  3   Gender        206209 non-null  object
#  4   STATE         206209 non-null  object
#  5   Age           206209 non-null  int64
#  6   date_joined   206209 non-null  object
#  7   n_dependants  206209 non-null  int64
#  8   fam_status    206209 non-null  object
#  9   income        206209 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 15.7+ MB

# %% [markdown]
# # Wrangling Customer Data

# %%
## Finding missing values
df_csm['Age'].value_counts(dropna = False)
# All columns were checked, no null/missing values present.
# Out:
# Age
# 19    3329
# 55    3317
# 51    3317
# 56    3306
# 32    3305
#       ...
# 65    3145
# 25    3127
# 66    3114
# 50    3102
# 36    3101
# Name: count, Length: 64, dtype: int64

# %%
#Renaming Columns
df_csm.rename(columns = {'fam_status' : 'Marital status'}, inplace = True)

# %%
df_csm.rename(columns = {'Surname' : 'Last_name'}, inplace = True)

# %%
df_csm.rename(columns = {'n_dependants' : 'Children'}, inplace = True)
df_csm.rename(columns = {'STATE' : 'State'}, inplace = True)
df_csm.rename(columns = {'First Name' : 'First_name'}, inplace = True)

# %%
df_csm.head()
# Out:
#   user_id First_name Last_name  Gender       State  Age date_joined  Children  \
# 0   26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017         3
# 1   33890   Patricia      Hart  Female  New Mexico   36    1/1/2017         0
# 2   65803    Kenneth    Farley    Male       Idaho   35    1/1/2017         2
# 3  125935   Michelle     Hicks  Female        Iowa   40    1/1/2017         0
# 4  130797        Ann   Gilmore  Female    Maryland   26    1/1/2017         1
#
#   Marital status  income
# 0        married  165665
# 1         single   59285
# 2        married   99568
# 3         single   42049
# 4        married   40374

# %%
df_csm.describe()
# Out:
#                  Age       Children         income
# count  206209.000000  206209.000000  206209.000000
# mean       49.501646       1.499823   94632.852548
# std        18.480962       1.118433   42473.786988
# min        18.000000       0.000000   25903.000000
# 25%        33.000000       0.000000   59874.000000
# 50%        49.000000       1.000000   93547.000000
# 75%        66.000000       3.000000  124244.000000
# max        81.000000       3.000000  593901.000000

# %%
##Changing data type to non-numeric string
df_csm['user_id'] = df_csm['user_id'].astype('str')

# %%
df_csm['user_id'].dtype
# Out:
# dtype('O')

# %% [markdown]
# # Wrangling Orders Data

# %%
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), index_col = False)

# %%
df_ords.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
## Order Dataframe descriptive statistics
df_ords.describe()
# Out:
#            order_id       user_id  order_number     order_dow  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01  2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01  2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00  1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01  3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01  5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02  6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# 75%         1.600000e+01            1.500000e+01
# ...

# %%
# Orders df cganging data types from a number to a string
df_ords['order_id'] = df_ords['order_id'].astype('str')

# %%
df_ords['user_id'] = df_ords['user_id'].astype('str')

# %%
df_ords['user_id'].dtypes
# Out:
# dtype('O')

# %%
df_ords['order_id'].dtypes
# Out:
# dtype('O')

# %%
#Renaming Columns
df_ords.rename(columns = {'orders_dow' : 'orders_day_of_week'}, inplace = True)

# %%
df_ords.head()
# Out:
#   order_id user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0  2539329       1    prior             1          2                  8
# 1  2398795       1    prior             2          3                  7
# 2   473747       1    prior             3          3                 12
# 3  2254736       1    prior             4          4                  7
# 4   431534       1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
## Step 4 'Busiest hour for placing orders'

# %%
#This formula is used because the column has multiple missing values
df_ords['order_hour_of_day'].value_counts(dropna = False)
# Out:
# order_hour_of_day
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: count, dtype: int64

# %% [markdown]
# 1000 is the the busiest hour for placing order

# %%
#Step 5: find the meaning behind a value of 4 in the "department_id" column within the df_prods dataframe using a data dictionary.
##Department DF

# %%
df_dep = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'departments.csv'), index_col = False)

# %%
data_dict = df_dep.to_dict('index')

# %%
data_dict
# Out:
# {0: {'department_id': 'department',
#   '1': 'frozen',
#   '2': 'other',
#   '3': 'bakery',
#   '4': 'produce',
#   '5': 'alcohol',
#   '6': 'international',
#   '7': 'beverages',
#   '8': 'pets',
#   '9': 'dry goods pasta',
#   '10': 'bulk',
#   '11': 'personal care',
#   '12': 'meat seafood',
#   '13': 'pantry',
#   '14': 'breakfast',
#   '15': 'canned goods',
#   '16': 'dairy eggs',
#   '17': 'household',
#   '18': 'babies',
#   '19': 'snacks',
#   '20': 'deli',
#   '21': 'missing'}}

# %%
# Step 6 subset showing only the breakfast sales items
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)

# %%
df_bfast = df_prods.loc[df_prods['department_id'].isin([3,14,16])]

# %%
df_bfast
# Out:
#        product_id                                       product_name  \
# 8               9                  Light Strawberry Blueberry Yogurt
# 27             28                                  Wheat Chex Cereal
# 33             34                                                NaN
# 57             58                              Whole Wheat Tortillas
# 67             68                            Pancake Mix, Buttermilk
# ...           ...                                                ...
# 49648       49644                                      Feta Crumbles
# 49660       49656                         Masada Kosher Pocket Bread
# 49662       49658                         Brie with Herbs Foil Wedge
# 49667       49663  Ultra Protein Power Crunch Peanut Butter N' Ho...
# 49690       49686                                   Artisan Baguette
#
#        aisle_id  department_id  prices
# 8           120             16     7.0
# 27          121             14    10.1
# ...

# %%
# Step 7 create a dinner subset
df_prods
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
df_dinner = df_prods.loc[df_prods['department_id'].isin([5,7,12,20])]

# %%
# Step 8: rows in df_dinner. 
df_dinner.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7650 entries, 2 to 49688
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     7650 non-null   int64
#  1   product_name   7647 non-null   object
#  2   aisle_id       7650 non-null   int64
#  3   department_id  7650 non-null   int64
#  4   prices         7650 non-null   float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 358.6+ KB

# %%
# Step 9 info on user_id 1
df_ords_user_1 = df_ords.loc[df_ords['user_id']=='1']

# %%
df_ords_user_1
# Out:
#    order_id user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329       1    prior             1          2                  8
# 1   2398795       1    prior             2          3                  7
# 2    473747       1    prior             3          3                 12
# 3   2254736       1    prior             4          4                  7
# 4    431534       1    prior             5          4                 15
# 5   3367565       1    prior             6          2                  7
# 6    550135       1    prior             7          1                  9
# 7   3108588       1    prior             8          1                 14
# 8   2295261       1    prior             9          1                 16
# 9   2550362       1    prior            10          4                  8
# 10  1187899       1    train            11          4                  8
#
#     days_since_prior_order
# 0                      NaN
# 1                     15.0
# ...

# %%
df_ords_user_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11 entries, 0 to 10
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   order_id                11 non-null     object
#  1   user_id                 11 non-null     object
#  2   eval_set                11 non-null     object
#  3   order_number            11 non-null     int64
#  4   order_dow               11 non-null     int64
#  5   order_hour_of_day       11 non-null     int64
#  6   days_since_prior_order  10 non-null     float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 704.0+ bytes

# %%
# Step 10 details on user behaviour
df_ords_user_1.describe()
# Out:
#        order_number  order_dow  order_hour_of_day  days_since_prior_order
# count     11.000000  11.000000          11.000000               10.000000
# mean       6.000000   2.636364          10.090909               19.000000
# std        3.316625   1.286291           3.477198                9.030811
# min        1.000000   1.000000           7.000000                0.000000
# 25%        3.500000   1.500000           7.500000               14.250000
# 50%        6.000000   3.000000           8.000000               19.500000
# 75%        8.500000   4.000000          13.000000               26.250000
# max       11.000000   4.000000          16.000000               30.000000

# %%
# Step 12 - Export df_ords to the "prepared folder"
df_ords.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_wrangled.csv'))

# %%
# Step 13 export the df_dep_t_new dataframe to "prepared folder"
## Transposing df_rep
df_dep.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
## Creating a new transposed dataframe.
df_dep_t = df_dep.T

# %%
df_dep.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
## Take the first row of df_dep_t
new_header = df_dep_t.iloc[0]

# %%
# Take the data under the header row for a new dataframe (df)
df_dep_t_new = df_dep_t[1:]

# %%
df_dep_t_new
# Out:
#                   0
# 1            frozen
# 2             other
# 3            bakery
# 4           produce
# 5           alcohol
# 6     international
# 7         beverages
# 8              pets
# 9   dry goods pasta
# 10             bulk
# 11    personal care
# 12     meat seafood
# 13           pantry
# 14        breakfast
# 15     canned goods
# 16       dairy eggs
# 17        household
# 18           babies
# 19           snacks
# 20             deli
# 21          missing

# %%
# Set the header row as the df header
df_dep_t_new.columns = new_header

# %%
df_dep_t_new.to_csv(os.path.join(path, '02 Data','Prepared Data', 'departments_wrangled.csv'))
